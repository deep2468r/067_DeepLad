# %% [markdown]
# ## Try SVM classifier on MNIST dataset, compare the preformance of linear, polynomial and RBF kernels.

# %%
import sys, os
import matplotlib.pyplot as plt
from sklearn import svm
from sklearn.model_selection import train_test_split
import numpy as np

# %%
from sklearn.datasets import load_digits

digits = load_digits()

X_train, X_test, y_train, y_test = train_test_split(digits.data, digits.target, test_size = 0.3, train_size = 0.2 ,random_state = 67)

# %% [markdown]
# ## Linear Model

# %%
linear_clf = svm.SVC(kernel='linear')
linear_clf.fit(X_train, y_train) #training

# predict
y_pred = linear_clf.predict(X_test)

# %%
from sklearn import metrics

# accuracy
print("Accuracy = ", metrics.accuracy_score(y_true=y_test, y_pred=y_pred), "\n")
# Out:
# Accuracy =  0.9574074074074074

# %% [markdown]
# ## Polynomial Model

# %%
poly_clf = svm.SVC(kernel='poly')
poly_clf.fit(X_train, y_train) #training

# predict
y_pred = poly_clf.predict(X_test)

# %%
# accuracy
print("Accuracy = ", metrics.accuracy_score(y_true=y_test, y_pred=y_pred), "\n")
# Out:
# Accuracy =  0.9592592592592593

# %% [markdown]
# ## RBF Model

# %%
rbf_clf = svm.SVC(kernel='rbf') 
rbf_clf.fit(X_train, y_train) #training

# predict
y_pred = rbf_clf.predict(X_test)

# %%
# accuracy
print("Accuracy = ", metrics.accuracy_score(y_true=y_test, y_pred=y_pred), "\n")
# Out:
# Accuracy =  0.9574074074074074
