# %% [markdown]
# **Perform all of the preprocessing tasks on any other text dataset**

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# importing libraries
import nltk
import matplotlib.pyplot as plt
import pandas as pd

# %%
import re
import string
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import TweetTokenizer

# %%
# Raw Text Analysis

random_text = """#FollowFriday @France_Inte @PKuchly57 @Milipol_Paris for being top engaged members in my community this week :)"""

remove_link_text = re.sub( r'https?:\/\/.*[\r\n]*', '', random_text )
remove_link_text = re.sub( r'#', '', remove_link_text )
print( remove_link_text )
# Out:
# FollowFriday @France_Inte @PKuchly57 @Milipol_Paris for being top engaged members in my community this week :)

# %%
print( '\033[92m' + random_text )
print( '\033[92m' + remove_link_text )
# Out:
# #FollowFriday @France_Inte @PKuchly57 @Milipol_Paris for being top engaged members in my community this week :)
# FollowFriday @France_Inte @PKuchly57 @Milipol_Paris for being top engaged members in my community this week :)

# %%
from nltk.tokenize import sent_tokenize

text = remove_link_text
#text = """Hello Mr. steve, how you doing? whats up? The weather is great, and city is awesome. how you doing? The sky is pinkish-blue. You shouldn't eat cardboard, how you doing?"""

# Download punkt
nltk.download("punkt")
tokenized_text = sent_tokenize(text)

print(tokenized_text)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ['FollowFriday @France_Inte @PKuchly57 @Milipol_Paris for being top engaged members in my community this week :)']

# %%
# Breaks paragraph into words
from nltk.tokenize import word_tokenize

tokenized_word = word_tokenize( text )

print( tokenized_word )
# Out:
# ['FollowFriday', '@', 'France_Inte', '@', 'PKuchly57', '@', 'Milipol_Paris', 'for', 'being', 'top', 'engaged', 'members', 'in', 'my', 'community', 'this', 'week', ':', ')']

# %%
# Frequency distribution
from nltk.probability import FreqDist

fdist = FreqDist( tokenized_word )
fdist.most_common(4)

# Frequency Distribution Plot
import matplotlib.pyplot as plt

fdist.plot( 30, cumulative = False, color = "green" )
plt.show()

# %%
# stop words
from nltk.corpus import stopwords

# download stopwords
nltk.download("stopwords")
stop_words = set( stopwords.words("english") )

print(stop_words)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# {'down', "you'd", 'aren', 'each', 'a', 'on', 'isn', 'itself', 'o', 'yourself', "mightn't", 'into', "shan't", 'having', 'd', 'was', 'those', 'ourselves', 'these', 'only', 'what', 'who', 'shan', "wouldn't", 'doing', 'for', 'them', "didn't", 'with', 'in', "couldn't", 'by', 'to', 'wouldn', 'mightn', 'between', 'above', 'does', "needn't", 'now', "isn't", 'or', 'mustn', 'were', 'while', 'the', 'which', 'my', 'yourselves', 'this', 'they', 'has', 'because', 'won', "don't", 'didn', 'had', "haven't", 'we', 'of', 'both', 'ma', 'his', 'again', 'such', 'here', 'just', 'it', "you'll", 'are', 'been', 'about', "should've", 'from', 'him', 'whom', 'don', 'nor', "aren't", 'theirs', 'is', 'all', 'up', "it's", 'hadn', "doesn't", 'during', 'out', 'not', 'very', "that'll", 'shouldn', 'before', 'am', "she's", 'most', 'weren', 'ours', 'm', "you're", 'its', 'some', 'an', "hasn't", 'couldn', 'if', 'haven', 'doesn', 'did', 'that', 'through', 'himself', "you've", 'off', 'as', 'more', 'when', 'other', 'no', 'do', "won't", 've', 'hasn', "weren't", 'once', 'their', 'be', 'against', 'how', 'have', 'being', 'few', 'so', 'our', 'should', 'own', 'ain', 'can', 'i', 'but', 'needn', 'he', 'why', 'where', 'after', 't', "wasn't", 'at', 'further', 'too', 'hers', 'then', 'themselves', 'wasn', 'there', 'than', 'her', 'will', 'me', "hadn't", 'any', 's', 'she', 'you', 'under', 'same', 'yours', 'myself', 'below', 'll', 're', "mustn't", 'herself', 'over', 'until', 'y', "shouldn't", 'and', 'your'}

# %%
filtered_sent=[]
for w in tokenized_word:
    if w not in stop_words:
        filtered_sent.append(w)

print( "Tokenized Sentence :- ", tokenized_word )
print( "Filterd Sentence :- ", filtered_sent )
# Out:
# Tokenized Sentence :-  ['FollowFriday', '@', 'France_Inte', '@', 'PKuchly57', '@', 'Milipol_Paris', 'for', 'being', 'top', 'engaged', 'members', 'in', 'my', 'community', 'this', 'week', ':', ')']
# Filterd Sentence :-  ['FollowFriday', '@', 'France_Inte', '@', 'PKuchly57', '@', 'Milipol_Paris', 'top', 'engaged', 'members', 'community', 'week', ':', ')']

# %%
# Stemming
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize

ps = PorterStemmer()

stemmed_words=[]
for w in filtered_sent:
    stemmed_words.append( ps.stem(w) )

print( "Filtered Sentence :- ", filtered_sent )
print( "Stemmed Sentence :-", stemmed_words )
# Out:
# Filtered Sentence :-  ['FollowFriday', '@', 'France_Inte', '@', 'PKuchly57', '@', 'Milipol_Paris', 'top', 'engaged', 'members', 'community', 'week', ':', ')']
# Stemmed Sentence :- ['followfriday', '@', 'france_int', '@', 'pkuchly57', '@', 'milipol_pari', 'top', 'engag', 'member', 'commun', 'week', ':', ')']

# %%
# Lexicon Normalization
# Performing stemming and Lemmatization

from nltk.stem.wordnet import WordNetLemmatizer

nltk.download('wordnet')
lem = WordNetLemmatizer()

from nltk.stem.porter import PorterStemmer
stem = PorterStemmer()

word = "breathing"
print("Lemmatized Word :- ", lem.lemmatize( word, "v" ) )
print("Stemmed Word :- ", stem.stem( word ) )
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# Lemmatized Word :-  breathe
# Stemmed Word :-  breath
